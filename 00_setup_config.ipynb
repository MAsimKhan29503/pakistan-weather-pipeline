# %% [markdown]
# ## Configuring storage paths and catalog/schema

# %%
storage_account_name = "internshipdlsa01"

raw_path = f"abfss://raw@{storage_account_name}.dfs.core.windows.net/"
processed_path = f"abfss://processed@{storage_account_name}.dfs.core.windows.net/"
gold_path = f"abfss://gold@{storage_account_name}.dfs.core.windows.net/"

spark.sql("USE CATALOG internship_databricks_ws")
spark.sql("USE SCHEMA default")

print("Config loaded: raw_path, processed_path, gold_path ready")
